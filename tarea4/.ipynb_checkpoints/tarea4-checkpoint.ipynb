# %%
import osmnx as ox
import numpy as np
import pandas as pd
import geopandas as gp
import folium
from shapely.geometry import Point, Polygon
import altair as alt

# %% [markdown]
# <p style = "color: blue; font-size :40px;text-align:center;font-family:Times New Roman"> Tarea 4

# %% [markdown]
# # 1. [50 puntos] Utilizando la biblioteca `altair` y conjunto de datos base de datos `IPS_cantonal.xlsx` realice lo siguiente:

# %%
datos = pd.read_excel('../datos/base-de-datos-IPS-cantonal.xlsx')
datos
# Out:
# /Users/promidat04/opt/anaconda3/lib/python3.9/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#     Cve        Cantón  Nutrición y Asistencia Médica Básica  \
# 0   101      SAN JOSE                             82.987394
# 1   102        ESCAZU                             85.931253
# 2   103  DESAMPARADOS                             88.541844
# 3   104      PURISCAL                             90.993459
# 4   105       TARRAZU                             91.495155
# ..  ...           ...                                   ...
# 76  702        POCOCI                             93.710271
# 77  703     SIQUIRRES                             95.130944
# 78  704     TALAMANCA                             84.478978
# 79  705        MATINA                             85.092291
# 80  706       GUACIMO                             93.563802
#
#     Agua y Saneamiento   Vivienda  Seguridad Personal  \
# 0            98.665964  63.891581           43.713222
# 1            98.121264  86.023111           52.939193
# 2            94.700064  80.789600           58.999818
# 3            89.766092  90.227325           86.085942
# 4            96.414943  88.021404           65.438845
# ..                 ...        ...                 ...
# 76           88.383142  74.219748           52.284697
# 77           62.759771  78.607393           51.885455
# 78           80.812963  26.828208           58.506535
# 79           90.308685  64.382709           49.398883
# 80           94.176628  81.462692           60.327747
#
#     Acceso a Conocimientos Básicos  Acceso a Información y Comunicaciones  \
# 0                        84.284809                              73.758822
# 1                        88.650664                              77.359311
# 2                        88.804140                              70.986816
# 3                        84.829898                              58.456934
# 4                        77.763379                              55.222121
# ..                             ...                                    ...
# 76                       85.629427                              56.824826
# 77                       84.434846                              54.077897
# 78                       68.188011                              42.608662
# 79                       80.095213                              49.114978
# 80                       75.897100                              55.044326
#
#     Salud y Bienestar  Sustentabilidad del Ecosistema  ...  \
# 0           64.570213                       39.810430  ...
# 1           67.819220                       64.554111  ...
# 2           68.089101                       48.467391  ...
# 3           76.552294                       65.577701  ...
# 4           77.395928                       71.499005  ...
# ..                ...                             ...  ...
# 76          81.059653                       53.672129  ...
# 77          77.828522                       57.988991  ...
# 78          69.068280                       76.325130  ...
# 79          83.942474                       61.683156  ...
# 80          77.258850                       65.307360  ...
#
#     Rendición de cuentas  Acceso a la cultura y recreación  \
# 0                   95.3                            20.552
# 1                   90.0                            15.573
# 2                   33.3                             3.071
# 3                   97.7                             5.454
# 4                   81.0                             8.600
# ..                   ...                               ...
# 76                  82.0                             3.425
# 77                  97.3                             1.937
# 78                  66.7                             6.187
# 79                  66.7                             0.265
# 80                  74.3                             0.242
#
#     Inclusión al adulto mayor  Inclusión a población con discapacidad  \
# 0                    5.252235                                7.709731
# 1                    6.169883                                6.741573
# 2                    5.102137                                8.366314
# 3                    8.805477                                6.519700
# 4                    4.359313                               10.572391
# ..                        ...                                     ...
# 76                  13.157369                               12.746757
# 77                  13.290150                               14.055829
# 78                  29.541864                               17.794572
# 79                  18.428751                               14.405915
# 80                  11.779141                               13.725490
#
#     Inclusión población indígena  Inclusión de migrantes  \
# 0                       7.919016               25.562775
# 1                       6.495726               10.226506
# 2                       9.358289               18.081342
# 3                       8.341232               27.045770
# 4                      33.012821               25.316456
# ..                           ...                     ...
# 76                     13.468939               25.725650
# 77                     17.743702               20.353282
# 78                     30.706153               28.525512
# 79                     28.922495               23.230386
# 80                     17.992424               19.198767
#
#     Inclusión de hogares con jefatura femenina  \
# 0                                    36.874519
# 1                                    29.850746
# 2                                    31.065089
# 3                                    17.241379
# 4                                    11.111111
# ..                                         ...
# 76                                   24.083770
# 77                                   15.277778
# 78                                   30.000000
# 79                                   15.151515
# 80                                   21.428571
#
#     Población con educación superior  Escolaridad promedio de las mujeres  \
# 0                          29.469448                             9.733187
# 1                          40.279616                            10.583268
# 2                          21.696907                             9.038890
# 3                          20.662035                             8.512712
# 4                          12.510132                             7.431191
# ..                               ...                                  ...
# 76                         11.816294                             7.428762
# 77                          9.480705                             7.287186
# 78                         10.315186                             6.904943
# 79                          7.153248                             6.892898
# 80                          8.714517                             7.004384
#
#     Población con educación técnica
# 0                          4.329589
# 1                          4.197981
# 2                          5.288635
# 3                          7.423228
# 4                          3.440599
# ..                              ...
# 76                         4.176034
# 77                         5.604915
# 78                         4.836683
# 79                         4.733763
# 80                         4.258113
#
# [81 rows x 64 columns]

# %%
datos["Tasa de robos y asaltos"]
# Out:
# 0     717.666962
# 1     174.150428
# 2     189.400740
# 3       8.699435
# 4      64.117510
#          ...
# 76    155.471215
# 77    205.379621
# 78     44.600546
# 79    191.989890
# 80     83.910667
# Name: Tasa de robos y asaltos, Length: 81, dtype: float64

# %% [markdown]
# ## a) Diseñe un gráfico que permita analizar la relación entre Tasa de robos y asaltos y Rezago escolar para los distintos cantones.

# %%
def quantile_norm(df_input):
    sorted_df = pd.DataFrame(np.sort(df_input.values,axis=0), index=df_input.index, columns=df_input.columns)
    mean_df = sorted_df.mean(axis=1)
    mean_df.index = np.arange(1, len(mean_df) + 1)
    quantile_df =df_input.rank(method="min").stack().astype(int).map(mean_df).unstack()
    return(quantile_df)

# %% [markdown]
# ## b) Utilizando la biblioteca `altair` replique el diseño del punto anterior.

# %%
alt.Chart(datos,title = "Relación Tasa de robos y asaltos con Rezago escolar."
                 ).mark_point().encode(
    x = alt.X('Tasa de robos y asaltos:Q', title = "Robos y Asaltos"),
    y = alt.Y('Rezago escolar:Q', title = "Rezago escolar"),
    color = alt.Color('Cantón', 
                      legend = alt.Legend(title = "Cantón")))
# Out:
# alt.Chart(...)

# %% [markdown]
# ## c) Interprete los resultados.

# %% [markdown]
# ## d) Diseñe un gráfico que permita analizar la relación entre Acceso a la cultura y recreación y Acceso a Educación Superior para los distintos cantones agrupando en 5 grupos según su Índice de Progreso Social, para crear los grupos puede utilizar las técnicas vista en la clase 2.

# %% [markdown]
# ## e) Utilizando la biblioteca `altair` replique el diseño del punto anterior.

# %%
datos['grupos'] = pd.cut(x = datos['Índice de Progreso Social']  , bins = 5)
datos['grupos'] = datos["grupos"].astype('str')

# %%
alt.Chart(datos,title = "Relación de Acceso a la cultura y Acceso a Educación Superior."
                 ).mark_point().encode(
    x = alt.X('Acceso a la cultura y recreación:Q', title = "Acceso a la cultura y recreación"),
    y = alt.Y('Acceso a Educación Superior:Q', title = "Acceso a Educación Superior"),
    color = alt.Color('grupos', 
                      legend = alt.Legend(title = "Grupos")))
# Out:
# alt.Chart(...)

# %% [markdown]
# ## f) Interprete los resultados.

# %% [markdown]
# # 3. [20 puntos] Utilizando la biblioteca `altair` y los datos de su preferencia diseñe al menos 3 gráficos siguiendo los siguiente requerimientos:

# %% [markdown]
# ## a) Uso de una paleta de colores personalizada.

# %% [markdown]
# ## b) Uso de anotaciones como título, subtítulo, etc.

# %% [markdown]
# ## c) Uso de selectores y tranformadores
